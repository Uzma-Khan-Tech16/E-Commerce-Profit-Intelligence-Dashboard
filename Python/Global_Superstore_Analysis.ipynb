# %% [markdown]
# # Global Superstore Business Intelligence Analysis
#
# ### Tools Used
# - Python
# - SQL
# - Power BI

# %% [markdown]
# ## Step 1 : Import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries Imported Successfully")
# Out:
# Libraries Imported Successfully

# %% [markdown]
# ## Step 2: Load the Dataset
#
# In this step, we will load the Global Superstore dataset into Python using Pandas and verify whether the dataset has been imported correctly.

# %%
df = pd.read_csv(r"C:/Users/kuzma/OneDrive/Desktop/DATA ANALYST/E-Commerce Profit Intelligence Dashboard/Dataset/Global_Superstore_uncleaned.csv", encoding="latin1")

# Display first 5 rows
df.head()
# Out:
#    ï»¿Row ID                  Order ID  Order Date   Ship Date     Ship Mode  \
# 0      40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014   First Class
# 1      26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014  Second Class
# 2      25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014   First Class
# 3      13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014   First Class
# 4      47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ...   Product ID    Category Sub-Category  \
# ...

# %% [markdown]
# ## Step 3: Data Understanding
#
# In this step, we will understand the structure of the dataset by checking its dimensions, column names, data types, and summary statistics.

# %%
# Display the number of rows and columns

print("Dataset Shape:", df.shape)
# Out:
# Dataset Shape: (1000, 24)

# %%
# Display all column names

df.columns
# Out:
# Index(['ï»¿Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %%
# Display dataset information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ï»¿Row ID       1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   object
#  3   Ship Date       1000 non-null   object
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   Postal Code     194 non-null    float64
#  9   City            1000 non-null   object
#  10  State           1000 non-null   object
#  11  Country         1000 non-null   object
#  12  Region          1000 non-null   object
#  13  Market          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
# ...

# %%
# Display summary statistics

df.describe()
# Out:
#           ï»¿Row ID   Postal Code        Sales    Quantity     Discount  \
# count   1000.000000    194.000000  1000.000000  1000.00000  1000.000000
# mean   25079.328000  53966.170103  1710.971470     5.55800     0.092840
# std    12897.726632  33734.306466  1259.239238     2.71846     0.148666
# min       58.000000   2920.000000     1.910000     1.00000     0.000000
# 25%    15118.750000  19134.000000   826.907500     4.00000     0.000000
# 50%    25084.500000  60564.000000  1585.115000     5.00000     0.000000
# 75%    34524.000000  88187.500000  2477.812500     7.00000     0.150000
# max    51284.000000  98198.000000  9892.740000    14.00000     0.800000
#
#             Profit  Shipping Cost
# count  1000.000000    1000.000000
# mean    288.920440     272.384897
# std     574.504782     176.160716
# min   -3059.820000       1.070000
# 25%      10.037500     209.827500
# 50%     190.685000     258.897500
# 75%     518.872500     351.070250
# max    4946.370000     923.630000

# %%
# Display first 10 rows

df.head(10)
# Out:
#    ï»¿Row ID                  Order ID  Order Date   Ship Date  \
# 0      40098  CA-2014-AB10015140-41954  11/11/2014  11/13/2014
# 1      26341    IN-2014-JR162107-41675    2/5/2014    2/7/2014
# 2      25330    IN-2014-CR127307-41929  10/17/2014  10/18/2014
# 3      13524   ES-2014-KM1637548-41667   1/28/2014   1/30/2014
# 4      47221   SG-2014-RH9495111-41948   11/5/2014   11/6/2014
# 5      22732    IN-2014-JM156557-41818   6/28/2014    7/1/2014
# 6      30570   IN-2012-TS2134092-41219   11/6/2012   11/8/2012
# 7      31192   IN-2013-MB1808592-41378   4/14/2013   4/18/2013
# 8      40099  CA-2014-AB10015140-41954  11/11/2014  11/13/2014
# 9      36258  CA-2012-AB10015140-40974    3/6/2012    3/7/2012
#
#         Ship Mode   Customer ID     Customer Name      Segment  Postal Code  \
# 0     First Class  AB-100151402     Aaron Bergman     Consumer      73120.0
# 1    Second Class     JR-162107     Justin Ritter    Corporate          NaN
# ...

# %% [markdown]
# ## Step 4: Data Quality Assessment
#
# In this step, we will assess the quality of the dataset by checking:
# - Missing values
# - Duplicate records
# - Incorrect column names
# - Data types

# %%
# Check missing values

missing_values = df.isnull().sum()

print("Missing Values in Each Column:")
missing_values
# Out:
# Missing Values in Each Column:
# ï»¿Row ID           0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Postal Code       806
# City                0
# State               0
# Country             0
# Region              0
# Market              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Cost       0
# Order Priority      0
# dtype: int64

# %%
# Total missing values

print("Total Missing Values :", df.isnull().sum().sum())
# Out:
# Total Missing Values : 806

# %%
# Check duplicate rows

print("Total Duplicate Rows :", df.duplicated().sum())
# Out:
# Total Duplicate Rows : 0

# %%
# Display data types

df.dtypes
# Out:
# ï»¿Row ID           int64
# Order ID           object
# Order Date         object
# Ship Date          object
# Ship Mode          object
# Customer ID        object
# Customer Name      object
# Segment            object
# Postal Code       float64
# City               object
# State              object
# Country            object
# Region             object
# Market             object
# Product ID         object
# Category           object
# Sub-Category       object
# Product Name       object
# Sales             float64
# Quantity            int64
# Discount          float64
# Profit            float64
# Shipping Cost     float64
# Order Priority     object
# dtype: object

# %%
# Number of unique values in each column

df.nunique()
# Out:
# ï»¿Row ID         1000
# Order ID           867
# Order Date         599
# Ship Date          613
# Ship Mode            4
# Customer ID        800
# Customer Name      496
# Segment              3
# Postal Code         76
# City               592
# State              341
# Country             93
# Region              22
# Market               5
# Product ID         529
# Category             3
# Sub-Category        17
# Product Name       529
# Sales              946
# Quantity            14
# Discount            20
# Profit             956
# Shipping Cost      971
# Order Priority       4
# dtype: int64

# %%
# Display column names

df.columns.tolist()
# Out:
# ['ï»¿Row ID',
#  'Order ID',
#  'Order Date',
#  'Ship Date',
#  'Ship Mode',
#  'Customer ID',
#  'Customer Name',
#  'Segment',
#  'Postal Code',
#  'City',
#  'State',
#  'Country',
#  'Region',
#  'Market',
#  'Product ID',
#  'Category',
#  'Sub-Category',
#  'Product Name',
#  'Sales',
#  'Quantity',
#  'Discount',
#  'Profit',
#  'Shipping Cost',
#  'Order Priority']

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Postal Code', 'City',
#        'State', 'Country', 'Region', 'Market', 'Product ID', 'Category',
#        'Sub-Category', 'Product Name', 'Sales', 'Quantity', 'Discount',
#        'Profit', 'Shipping Cost', 'Order Priority'],
#       dtype='object')

# %% [markdown]
# ## Step 5: Data Cleaning
#
# In this step, we will clean the dataset by:
# - Renaming incorrect column names
# - Converting date columns
# - Checking missing values
# - Checking duplicate records

# %%
# Rename incorrect column name

df.rename(columns={'ï»¿Row ID': 'Row ID'}, inplace=True)

print("Column renamed successfully!")
# Out:
# Column renamed successfully!

# %%
# Convert date columns

df["Order Date"] = pd.to_datetime(df["Order Date"])

df["Ship Date"] = pd.to_datetime(df["Ship Date"])

print("Date columns converted successfully.")
# Out:
# Date columns converted successfully.

# %%
# Verify datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Row ID          1000 non-null   int64
#  1   Order ID        1000 non-null   object
#  2   Order Date      1000 non-null   datetime64[ns]
#  3   Ship Date       1000 non-null   datetime64[ns]
#  4   Ship Mode       1000 non-null   object
#  5   Customer ID     1000 non-null   object
#  6   Customer Name   1000 non-null   object
#  7   Segment         1000 non-null   object
#  8   Postal Code     194 non-null    float64
#  9   City            1000 non-null   object
#  10  State           1000 non-null   object
#  11  Country         1000 non-null   object
#  12  Region          1000 non-null   object
#  13  Market          1000 non-null   object
#  14  Product ID      1000 non-null   object
#  15  Category        1000 non-null   object
#  16  Sub-Category    1000 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Row ID              0
# Order ID            0
# Order Date          0
# Ship Date           0
# Ship Mode           0
# Customer ID         0
# Customer Name       0
# Segment             0
# Postal Code       806
# City                0
# State               0
# Country             0
# Region              0
# Market              0
# Product ID          0
# Category            0
# Sub-Category        0
# Product Name        0
# Sales               0
# Quantity            0
# Discount            0
# Profit              0
# Shipping Cost       0
# Order Priority      0
# dtype: int64

# %% [markdown]
# # Observation:
# # Postal Code contains 806 missing values.
# # Since this is a global dataset and postal codes are unavailable
# # for many countries, the column will be retained.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Step 6: Feature Engineering
#
# In this step, we will create new columns from the existing data to perform better business analysis and build more insightful dashboards.

# %%
# Create Year, Month, Month Name and Quarter

df["Order Year"] = df["Order Date"].dt.year

df["Order Month"] = df["Order Date"].dt.month

df["Month Name"] = df["Order Date"].dt.month_name()

df["Quarter"] = df["Order Date"].dt.quarter

print("Date features created successfully.")
# Out:
# Date features created successfully.

# %%
# Calculate Shipping Days

df["Shipping Days"] = (df["Ship Date"] - df["Order Date"]).dt.days

print("Shipping Days column created successfully.")
# Out:
# Shipping Days column created successfully.

# %%
# Calculate Profit Margin (%)

df["Profit Margin (%)"] = (df["Profit"] / df["Sales"]) * 100

print("Profit Margin column created successfully.")
# Out:
# Profit Margin column created successfully.

# %%
df.head()
# Out:
#    Row ID                  Order ID Order Date  Ship Date     Ship Mode  \
# 0   40098  CA-2014-AB10015140-41954 2014-11-11 2014-11-13   First Class
# 1   26341    IN-2014-JR162107-41675 2014-02-05 2014-02-07  Second Class
# 2   25330    IN-2014-CR127307-41929 2014-10-17 2014-10-18   First Class
# 3   13524   ES-2014-KM1637548-41667 2014-01-28 2014-01-30   First Class
# 4   47221   SG-2014-RH9495111-41948 2014-11-05 2014-11-06      Same Day
#
#     Customer ID     Customer Name      Segment  Postal Code           City  \
# 0  AB-100151402     Aaron Bergman     Consumer      73120.0  Oklahoma City
# 1     JR-162107     Justin Ritter    Corporate          NaN     Wollongong
# 2     CR-127307      Craig Reiter     Consumer          NaN       Brisbane
# 3    KM-1637548  Katherine Murray  Home Office          NaN         Berlin
# 4    RH-9495111       Rick Hansen     Consumer          NaN          Dakar
#
#    ... Discount  Profit Shipping Cost Order Priority Order Year Order Month  \
# ...

# %% [markdown]
# # Step 7: Sales Analysis
#
# In this section, we will analyze the overall business performance by calculating key business metrics (KPIs).

# %%
# ==========================================
# Business KPIs
# ==========================================

total_sales = df["Sales"].sum()
total_profit = df["Profit"].sum()
total_orders = df["Order ID"].nunique()
total_customers = df["Customer ID"].nunique()
total_products = df["Product ID"].nunique()
avg_order_value = total_sales / total_orders

print("========== BUSINESS KPIs ==========")
print(f"Total Sales      : ${total_sales:,.2f}")
print(f"Total Profit     : ${total_profit:,.2f}")
print(f"Total Orders     : {total_orders}")
print(f"Total Customers  : {total_customers}")
print(f"Total Products   : {total_products}")
print(f"Average Order Value : ${avg_order_value:,.2f}")
# Out:
# ========== BUSINESS KPIs ==========
# Total Sales      : $1,710,971.47
# Total Profit     : $288,920.44
# Total Orders     : 867
# Total Customers  : 800
# Total Products   : 529
# Average Order Value : $1,973.44

# %% [markdown]
# ## Monthly Sales Trend
#
# This analysis helps identify seasonal patterns and monthly sales performance.

# %%
# Monthly Sales Trend

monthly_sales = (
    df.groupby("Month Name")["Sales"]
      .sum()
      .reindex([
          "January","February","March","April","May","June",
          "July","August","September","October","November","December"
      ])
)

monthly_sales
# Out:
# Month Name
# January      110939.14
# February      94091.23
# March         83064.62
# April         86287.99
# May          127209.72
# June         185103.16
# July          82563.72
# August       190780.27
# September    177697.76
# October      156310.63
# November     191481.01
# December     225442.22
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.plot(monthly_sales.index,
         monthly_sales.values,
         marker='o',
         linewidth=2)

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.grid(True)

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Observe which month has the highest sales.
# - Identify the lowest-performing month.
# - Look for any seasonal trends.
# - These insights can help businesses plan inventory and marketing campaigns.

# %% [markdown]
# ## Category Analysis
#
# This section analyzes the performance of each product category based on Sales and Profit.

# %%
# Sales by Category

category_sales = (
    df.groupby("Category")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

category_sales
# Out:
# Category
# Technology         756983.02
# Furniture          601492.31
# Office Supplies    352496.14
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(category_sales.index, category_sales.values)

plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")

plt.show()

# %%
category_profit = (
    df.groupby("Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

category_profit
# Out:
# Category
# Technology         145068.68
# Furniture           82188.95
# Office Supplies     61662.81
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(8,5))

plt.bar(category_profit.index, category_profit.values)

plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify the category with the highest sales.
# - Compare whether the highest-selling category is also the most profitable.
# - Highlight categories that may need pricing or marketing improvements.

# %% [markdown]
# ## Sub-Category Analysis

# %%
subcategory_sales = (
    df.groupby("Sub-Category")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

subcategory_sales
# Out:
# Sub-Category
# Phones         417939.31
# Appliances     289711.30
# Bookcases      240688.73
# Copiers        231104.67
# Chairs         179648.44
# Tables         179292.88
# Machines        71366.87
# Storage         37592.32
# Accessories     36572.17
# Binders         19751.19
# Supplies         2037.92
# Furnishings      1862.26
# Paper            1816.57
# Art               904.55
# Fasteners         513.44
# Envelopes         114.06
# Labels             54.79
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.bar(subcategory_sales.index, subcategory_sales.values)

plt.title("Sales by Sub-Category")

plt.xlabel("Sub-Category")

plt.ylabel("Sales")

plt.xticks(rotation=90)

plt.show()

# %%
subcategory_profit = (
    df.groupby("Sub-Category")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

subcategory_profit
# Out:
# Sub-Category
# Phones         75119.47
# Copiers        52315.19
# Appliances     48518.99
# Bookcases      45483.14
# Chairs         23245.88
# Tables         13051.69
# Machines        8992.06
# Accessories     8641.96
# Binders         7435.09
# Storage         4490.04
# Paper            806.32
# Furnishings      408.24
# Fasteners        246.47
# Art              191.87
# Envelopes         42.02
# Labels            21.86
# Supplies         -89.85
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.bar(subcategory_profit.index, subcategory_profit.values)

plt.title("Profit by Sub-Category")

plt.xlabel("Sub-Category")

plt.ylabel("Profit")

plt.xticks(rotation=90)

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Determine the most profitable sub-category.
# - Identify sub-categories with low sales but high profit.
# - Highlight sub-categories that require strategic improvement.

# %% [markdown]
# ## Customer Analysis
#
# This section identifies the highest-value customers based on total sales and total profit.

# %%
#Top 10 Customers by Sales

top_customers = (
    df.groupby("Customer Name")["Sales"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

top_customers
# Out:
# Customer Name
# Adrian Barton      17307.24
# Dave Poirier       12871.07
# Vivek Grady        12800.38
# Adam Bellavance    11465.85
# Fred Hopkins       11294.06
# Dave Brooks        10705.87
# John Huston        10565.05
# Brad Norvell       10367.92
# Anne McFarland      9904.74
# Susan Pistek        9548.94
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.barh(top_customers.index, top_customers.values)

plt.title("Top 10 Customers by Sales")

plt.xlabel("Sales")

plt.ylabel("Customer")

plt.gca().invert_yaxis()

plt.show()

# %%
# Top 10 Customers by Profit
top_profit_customers = (
    df.groupby("Customer Name")["Profit"]
      .sum()
      .sort_values(ascending=False)
      .head(10)
)

top_profit_customers
# Out:
# Customer Name
# Adrian Barton        6602.41
# Dave Poirier         4280.00
# Patrick Jones        3979.08
# Cynthia Arntzen      3598.23
# Adam Bellavance      3575.72
# Susan Pistek         3478.92
# Maria Bertelson      3246.99
# Patrick O'Donnell    3215.38
# Jane Waco            3170.07
# Carol Adams          3135.84
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.barh(top_profit_customers.index,
         top_profit_customers.values)

plt.title("Top 10 Customers by Profit")

plt.xlabel("Profit")

plt.ylabel("Customer")

plt.gca().invert_yaxis()

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify the highest revenue-generating customers.
# - Compare whether the same customers also generate the highest profit.
# - Recommend loyalty programs for high-value customers.

# %% [markdown]
# ## Market Analysis
#
# In this section, we analyze the performance of different markets based on Sales and Profit.

# %%
# Sales by Market

market_sales = (
    df.groupby("Market")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

market_sales
# Out:
# Market
# Asia Pacific    800511.75
# Europe          503568.21
# LATAM           236263.49
# Africa          115205.93
# USCA             55422.09
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.bar(market_sales.index, market_sales.values)

plt.title("Sales by Market")

plt.xlabel("Market")

plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
market_profit = (
    df.groupby("Market")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

market_profit
# Out:
# Market
# Asia Pacific    125049.47
# Europe           89122.08
# LATAM            34929.35
# Africa           27541.85
# USCA             12277.69
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(10,5))

plt.bar(market_profit.index, market_profit.values)

plt.title("Profit by Market")

plt.xlabel("Market")

plt.ylabel("Profit")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify the highest-performing market.
# - Compare sales and profit across all markets.
# - Recommend focusing future investments on high-performing markets while improving low-performing ones.

# %% [markdown]
# ## Region Analysis
#
# This analysis evaluates sales and profit performance across different regions.

# %%
region_sales = (
    df.groupby("Region")["Sales"]
      .sum()
      .sort_values(ascending=False)
)

region_sales
# Out:
# Region
# Western Europe       259576.28
# Oceania              220809.08
# Southern Asia        205466.26
# Eastern Asia         193590.60
# Southeastern Asia    147337.60
# Central America      140966.21
# Northern Europe      103888.63
# Southern Europe       94441.11
# South America         64550.54
# Eastern Europe        45662.19
# Central Africa        33810.48
# Western Asia          33308.21
# Caribbean             30746.74
# North Africa          26266.44
# Southern Africa       22262.28
# Eastern Africa        17387.94
# Central US            17187.94
# Western US            16729.95
# Western Africa        15478.79
# Eastern US            12256.44
# Southern US            8360.75
# Canada                  887.01
# Name: Sales, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.bar(region_sales.index,
        region_sales.values)

plt.title("Sales by Region")

plt.xlabel("Region")

plt.ylabel("Sales")

plt.xticks(rotation=45)

plt.show()

# %%
region_profit = (
    df.groupby("Region")["Profit"]
      .sum()
      .sort_values(ascending=False)
)

region_profit
# Out:
# Region
# Eastern Asia         37911.16
# Southern Asia        37536.60
# Oceania              33777.56
# Western Europe       32783.40
# Northern Europe      23552.73
# Central America      21741.95
# Southern Europe      20557.50
# Eastern Europe       12228.45
# Southeastern Asia    10561.80
# Central Africa        9668.22
# South America         7723.58
# North Africa          7416.42
# Central US            5676.02
# Caribbean             5463.82
# Western Asia          5262.35
# Southern Africa       4876.32
# Eastern Africa        4302.72
# Eastern US            2544.89
# Western US            2458.34
# Southern US           1384.72
# Western Africa        1278.17
# Canada                 213.72
# Name: Profit, dtype: float64

# %%
plt.figure(figsize=(12,6))

plt.bar(region_profit.index,
        region_profit.values)

plt.title("Profit by Region")

plt.xlabel("Region")

plt.ylabel("Profit")

plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify the best-performing regions.
# - Highlight regions generating high sales but lower profits.
# - Recommend region-specific strategies to improve profitability.

# %% [markdown]
# ## Discount vs Profit Analysis
#
# This analysis helps determine whether higher discounts negatively impact profitability.

# %%
plt.figure(figsize=(10,6))

plt.scatter(df["Discount"], df["Profit"], alpha=0.6)

plt.title("Discount vs Profit")

plt.xlabel("Discount")

plt.ylabel("Profit")

plt.grid(True)

plt.show()

# %%
# Correlation between Discount and Profit

correlation = df["Discount"].corr(df["Profit"])

print(f"Correlation between Discount and Profit: {correlation:.2f}")
# Out:
# Correlation between Discount and Profit: -0.51

# %% [markdown]
# ### Business Insight
#
# - Analyze whether higher discounts reduce profitability.
# - Identify if there is a negative correlation.
# - Recommend optimized discount strategies to maximize profit.

# %% [markdown]
# ## Shipping Analysis
#
# This section evaluates shipping performance using shipping days and shipping modes.

# %%
# Average Shipping Days

average_shipping = df["Shipping Days"].mean()

print(f"Average Shipping Days : {average_shipping:.2f}")
# Out:
# Average Shipping Days : 3.02

# %%
#Shipping Mode Analysis

ship_mode = df["Ship Mode"].value_counts()

ship_mode
# Out:
# Ship Mode
# Standard Class    343
# First Class       317
# Second Class      239
# Same Day          101
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))

plt.bar(ship_mode.index, ship_mode.values)

plt.title("Orders by Shipping Mode")

plt.xlabel("Shipping Mode")

plt.ylabel("Number of Orders")

plt.xticks(rotation=20)

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify the most frequently used shipping mode.
# - Analyze shipping efficiency.
# - Recommend improvements to reduce delivery time and cost.

# %% [markdown]
# ## Correlation Analysis
#
# Correlation analysis helps identify relationships between numerical variables.

# %%
# Correlation Matrix

correlation_matrix = df[
    ["Sales", "Profit", "Quantity", "Discount", "Shipping Cost"]
].corr()

correlation_matrix
# Out:
#                   Sales    Profit  Quantity  Discount  Shipping Cost
# Sales          1.000000  0.533676  0.555691 -0.187997       0.644891
# Profit         0.533676  1.000000  0.154481 -0.505190       0.290593
# Quantity       0.555691  0.154481  1.000000  0.034045       0.356324
# Discount      -0.187997 -0.505190  0.034045  1.000000      -0.169216
# Shipping Cost  0.644891  0.290593  0.356324 -0.169216       1.000000

# %%
plt.figure(figsize=(8,6))

sns.heatmap(
    correlation_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %% [markdown]
# ### Business Insight
#
# - Identify strong positive and negative correlations.
# - Understand how Sales, Profit, Discount, Quantity, and Shipping Cost are related.
# - Use these insights to support business decision-making.

# %% [markdown]
# # Executive Business Insights
#
# Based on the exploratory data analysis, the following key business insights were identified.

# %% [markdown]
# ## Key Business Insights
#
# 1. The Asia Pacific market generated the highest revenue, making it the strongest-performing market in terms of overall sales.
#
# 2. Technology was the most profitable product category, indicating strong customer demand and higher profit margins compared to other categories.
#
# 3. Western Europe contributed the highest regional sales, highlighting it as one of the company's key revenue-generating regions.
#
# 4. A negative correlation was observed between discounts and profit, indicating that higher discounts generally reduce overall profitability.
#
# 5. The average shipping time was 3.02 days, suggesting an efficient order fulfillment process across the business.
#
# 6. The highest-value customer generated approximately $17,307.24 in total sales, emphasizing the importance of customer retention and loyalty programs.
#
# 7. Standard Class was the most frequently used shipping mode, indicating it is the preferred delivery option for customers.
#
# 8. Several products generated high sales but low profit, suggesting that excessive discounts or high operational costs may be affecting profitability.
#
# 9. Profitability varied significantly across different markets, indicating opportunities to improve pricing strategies and operational efficiency in lower-performing markets.
#
# 10. The company should focus on improving profitability in low-performing regions while continuing to invest in high-performing markets such as Asia Pacific and Western Europe to sustain long-term growth.

# %% [markdown]
# # Business Recommendations
#
# ### Recommendation 1
# Review discount strategies for products with consistently low profit margins.
#
# ### Recommendation 2
# Increase inventory for high-performing product categories.
#
# ### Recommendation 3
# Develop customer loyalty programs for high-value customers.
#
# ### Recommendation 4
# Improve operational efficiency in low-performing regions.
#
# ### Recommendation 5
# Optimize shipping methods to reduce delivery time and logistics costs.

# %%
# Export cleaned dataset

df.to_csv("C:/Users/kuzma/OneDrive/Desktop/DATA ANALYST/E-Commerce Profit Intelligence Dashboard/Dataset/Global_Superstore_cleaned.csv", index=False)

print("Cleaned dataset exported successfully!")
# Out:
# Cleaned dataset exported successfully!

# %%
import pandas as pd

df = pd.read_csv("C:/Users/kuzma/OneDrive/Desktop/DATA ANALYST/E-Commerce Profit Intelligence Dashboard/Dataset/Global_Superstore_cleaned.csv")

print("Rows:", len(df))
print(df.tail())
# Out:
# Rows: 1000
#      Row ID                  Order ID  Order Date   Ship Date       Ship Mode  \
# 995   24278   IN-2015-JF1541527-42095  2015-04-01  2015-04-05  Standard Class
# 996   36249  CA-2015-AS10225140-42347  2015-12-09  2015-12-13    Second Class
# 997   30517   IN-2014-CK1259592-41929  2014-10-17  2014-10-19    Second Class
# 998    1408   MX-2014-SS2014018-41658  2014-01-19  2014-01-26  Standard Class
# 999   20944  ID-2015-RP19855130-42348  2015-12-10  2015-12-14  Standard Class
#
#       Customer ID      Customer Name    Segment  Postal Code           City  \
# 995    JF-1541527  Jennifer Ferguson   Consumer          NaN       Liaoyang
# 996  AS-102251404  Alan Schoenberger  Corporate      94109.0  San Francisco
# 997    CK-1259592       Clytie Kelty   Consumer          NaN          Taupo
# 998    SS-2014018   Saphhira Shifley  Corporate          NaN     AraguaÃ­na
# 999   RP-19855130           Roy Phan  Corporate          NaN        Bangkok
#
# ...

# %%
# MySQL_Database
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL

# Read CSV
csv_path = r"C:\Users\kuzma\OneDrive\Desktop\DATA ANALYST\E-Commerce Profit Intelligence Dashboard\Dataset\Global_Superstore_cleaned.csv"

df = pd.read_csv(csv_path)

print("CSV Rows :", len(df))
print("CSV Columns :", len(df.columns))

# MySQL Connection
connection_url = URL.create(
    drivername="mysql+pymysql",
    username="root",
    password="Uzma@1609",
    host="localhost",
    port=3306,
    database="global_superstore_db"
)

engine = create_engine(connection_url)

# Test Connection
with engine.connect() as conn:
    print("✅ Connected Successfully!")

# Import Data
df.to_sql(
    name="global_superstore",
    con=engine,
    if_exists="replace",
    index=False,
    chunksize=500
)

print("✅ Data Imported Successfully!")
print("Rows Imported:", len(df))
# Out:
# CSV Rows : 1000
# CSV Columns : 30
# ✅ Connected Successfully!
# ✅ Data Imported Successfully!
# Rows Imported: 1000
